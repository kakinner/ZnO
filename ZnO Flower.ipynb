# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv("ZnO Flower.txt",sep='\t',skiprows=(1),)
print(df1)
df2=pd.read_csv("ZnO_Flower_Fake.txt",sep='\t',skiprows=(1),)
print(df2)
# Out:
#       2θ, °  Intensity, cps
# 0     15.00        9016.541
# 1     15.01        9192.578
# 2     15.02        9272.621
# 3     15.03        9335.913
# 4     15.04        9231.915
# ...     ...             ...
# 6495  79.95        3878.438
# 6496  79.96        3686.728
# 6497  79.97        3602.460
# 6498  79.98        3404.352
# 6499  79.99        3483.458
#
# [6500 rows x 2 columns]
#       2θ, °  Intensity, cps
# 0     15.00        9016.541
# 1     15.01        9192.578
# 2     15.02        9272.621
# 3     15.03        9335.913
# 4     15.04        9231.915
# ...     ...             ...
# 6495  79.95        3878.438
# 6496  79.96        3686.728
# 6497  79.97        3602.460
# 6498  79.98        3404.352
# 6499  79.99        3483.458
#
# [6500 rows x 2 columns]

# %%
theta1=df1['2θ, °']
Intensity1=df1['Intensity, cps']

theta2=df2['2θ, °']
Intensity2=df2['Intensity, cps']

# %%
fig, (ax1,ax2) = plt.subplots(nrows=2, sharex=True, subplot_kw=dict(frameon=False))

plt.subplots_adjust(hspace=.0)
ax1.grid()
ax2.grid()

ax1.plot(theta1, Intensity1, color='green', label='ZnO Flower')
ax1.legend(['ZnO Flower'])
ax1.set_title('pXRD of ZnO Flowers')
ax1.set_ylabel('Intensity, cps')

ax2.plot(theta2, Intensity2, color='blue', label='ZnO Flower Fake')
ax2.legend(['ZnO Flower Fake'])
ax2.set_xlabel('2θ, °')
ax2.set_ylabel('Intensity, cps')
# Out:
# Text(0, 0.5, 'Intensity, cps')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-ba3245a49de7> in <module>
#       1 ax1 = df1.plot(kind='line',x='2θ, °',y='Intensity, cps',color='green')
# ----> 2 ax.set_ylabel('Intensity, cps')
#       3 ax2 = df2.plot(kind='line',x='2θ, °',y='Intensity, cps',color='red')
#       4 ax.set_ylabel('Intensity, cps')
#
# NameError: name 'ax' is not defined
